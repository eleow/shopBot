# %%
import pandas as pd

# %%
df1 = pd.read_excel('/Users/shashanknigam/downloads/nlp_project/shopBot/webscraping/treoo_dataset/treoo_earphone_headphone_directory.xls',index_col = 0)

# %%
df2 = pd.read_excel('/Users/shashanknigam/downloads/nlp_project/shopBot/webscraping/AmazonDataSet/ProductDictionary.xlsx',index_col=0)

# %%
df3 = pd.read_excel('/Users/shashanknigam/downloads/nlp_project/shopBot/webscraping/AmazonDataSet/ProductDetails.xlsx',index_col=0)

# %%
df1=df1[['Product Name','Product URL','Product Price','Organziation','ProductModelName','ProductFeatures']]

# %%
df1
# Out:
#                                            Product Name  \
# 0                      1MORE H1005 Spearhead VR headset
# 1                            Adidas Original by Monster
# 2     AfterShokz Aeropex Wireless Bluetooth Bone Con...
# 3                                  AfterShokz Trekz Air
# 4                             AfterShokz Trekz Titanium
# ...                                                 ...
# 1639                             Zero Audio Carbo Basso
# 1640                            Zero Audio Carbo Doppio
# 1641                           Zero Audio Carbo Singolo
# 1642                            Zero Audio Carbo Tenore
# 1643                                   Zero Audio Duoza
#
#                                             Product URL Product Price  \
# 0     http://store.treoo.com/1more-h1005-spearhead-v...     S$149.00
# 1     http://store.treoo.com/adidas-original-by-mons...     S$489.00
# 2     http://store.treoo.com/aftershokz-aeropex-wire...     S$249.00
# ...

# %%
df2=df2[['ASIN','Name','Organziation','ProductModelName','ProductFeatures']]

# %%
df2["Price"] = df3['Price']

# %%
df2.columns = ['ASIN','Name','Org','Model','Feature','Price']

# %%
df2['URL']="https://www.amazon.com/dp/"+df2['ASIN']

# %%
df2
# Out:
#           ASIN                                               Name       Org  \
# 0   B07Q9MJKBV                Bose 700 Over-Ear Headphones, Black      Bose
# 0   B07RCJ48R2  Sony WH-CH700N Wireless Noise Cancelling Headp...      Sony
# 0   B07NXDPLJ9  Bose QuietComfort 35 II Wireless Bluetooth Hea...      Bose
# 0   B07HRBF5GH  Bluetooth Wireless Headphones Over Ear Noise C...       NaN
# 0   B00X9KV0HU  Bose QuietComfort 20 Acoustic Noise Cancelling...      Bose
# ..         ...                                                ...       ...
# 0   B073F7Q22R  Rockpapa Star On Ear Headphones Foldable, Adju...  Rockpapa
# 0   B07N7RL5J3  Ruckus Earplug Earbuds | OSHA Compliant Noise ...    Ruckus
# 0   B07W47XLFS  Wireless Headphones, APEKX True Wireless Bluet...       NaN
# 0   B083JXMXJM  (2Pack)Headphone Adapter Jack for iPhone Xs/Xs...       NaN
# 0   B07ZCL7XWJ  Equinox in-Ear Headphones for The Oculus Quest...      VRej
#
#                                                 Model  \
# ...

# %%
df1.columns=['Name','URL','Price','Org','Model','Feature']

# %%
df = df2.append(df1)

# %%
df.to_excel('ProductDetailsPricesURLs.xlsx')

# %%
df.drop_duplicate(subset=)
# Out:
#             ASIN                                               Name  \
# 0     B07Q9MJKBV                Bose 700 Over-Ear Headphones, Black
# 0     B07RCJ48R2  Sony WH-CH700N Wireless Noise Cancelling Headp...
# 0     B07NXDPLJ9  Bose QuietComfort 35 II Wireless Bluetooth Hea...
# 0     B07HRBF5GH  Bluetooth Wireless Headphones Over Ear Noise C...
# 0     B00X9KV0HU  Bose QuietComfort 20 Acoustic Noise Cancelling...
# ...          ...                                                ...
# 1639         NaN                             Zero Audio Carbo Basso
# 1640         NaN                            Zero Audio Carbo Doppio
# 1641         NaN                           Zero Audio Carbo Singolo
# 1642         NaN                            Zero Audio Carbo Tenore
# 1643         NaN                                   Zero Audio Duoza
#
#              Org                                        Model  \
# 0           Bose                                         700
# ...
